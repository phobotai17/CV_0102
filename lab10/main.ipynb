# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.36-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.23.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (2.32.3)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: torch>=1.8.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (2.10.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (0.25.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from ultralytics) (7.0.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.39.3-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting polars-runtime-32==1.39.3 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.39.3-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: setuptools in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bototduoicauvong/myenv/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.4.36-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.4 kB/s eta 0:00:00a 0:00:05
# Downloading polars-1.39.3-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 43.3 kB/s eta 0:00:00a 0:00:01
# Downloading polars_runtime_32-1.39.3-cp310-abi3-macosx_11_0_arm64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 508.9 kB/s eta 0:00:0000:0100:03
# Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 549.8 kB/s eta 0:00:0000:0100:02
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: scipy, polars-runtime-32, polars, ultralytics-thop, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [ultralytics] [ultralytics]me-32]
# Successfully installed polars-1.39.3 polars-runtime-32-1.39.3 scipy-1.17.1 ultralytics-8.4.36 ultralytics-thop-2.0.18
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

from ultralytics import solutions

cap = cv2.VideoCapture("orange.mp4")
assert cap.isOpened(), "Error reading video file"

# region_points = [(20, 400), (1080, 400)]                                      # line counting
region_points = [[5, 164], [1134, 177], [1087, 531], [60, 488], [9, 152]]  # rectangular region
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]   # polygon region

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("object_counting_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# Initialize object counter object
counter = solutions.ObjectCounter(
    show=True,  # display the output
    region=region_points,  # pass region points
    model="yolo26n.pt",  # model="yolo26n-obb.pt" for object counting with OBB model.
    # classes=[0, 2],  # count specific classes, e.g., person and car with the COCO pretrained model.
    # tracker="botsort.yaml",  # choose trackers, e.g., "bytetrack.yaml"
)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = counter(im0)

    # print(results)  # access the output

    video_writer.write(results.plot_im)  # write the processed frame.

cap.release()
video_writer.release()
cv2.destroyAllWindows()  # destroy all opened windows
# Out:
# Ultralytics Solutions: ✅ {'source': None, 'model': 'yolo26n.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': [[5, 164], [1134, 177], [1087, 531], [60, 488], [9, 152]], 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': True, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# WARNING ⚠️ No tracks found.
# 0: 720x1280 30.8ms,
# Speed: 48.9ms track, 30.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 1: 720x1280 15.1ms,
# Speed: 38.6ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 2: 720x1280 15.6ms,
# Speed: 34.4ms track, 15.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 3: 720x1280 15.2ms,
# Speed: 31.0ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 4: 720x1280 15.0ms,
# Speed: 31.5ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 5: 720x1280 14.8ms,
# Speed: 30.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 6: 720x1280 15.7ms,
# Speed: 32.0ms track, 15.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 7: 720x1280 15.0ms,
# Speed: 31.3ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 8: 720x1280 14.8ms,
# Speed: 31.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 9: 720x1280 15.4ms,
# Speed: 34.0ms track, 15.4ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 10: 720x1280 15.0ms,
# Speed: 33.5ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 11: 720x1280 15.3ms,
# Speed: 34.3ms track, 15.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 12: 720x1280 15.7ms,
# Speed: 34.0ms track, 15.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 13: 720x1280 16.5ms,
# Speed: 32.8ms track, 16.5ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 14: 720x1280 14.1ms,
# Speed: 31.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 15: 720x1280 15.0ms,
# Speed: 62.5ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 16: 720x1280 15.2ms,
# Speed: 30.9ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 17: 720x1280 14.9ms,
# Speed: 30.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 18: 720x1280 15.1ms,
# Speed: 29.8ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 19: 720x1280 14.8ms,
# Speed: 30.2ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 20: 720x1280 21.9ms,
# Speed: 29.7ms track, 21.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 21: 720x1280 16.1ms,
# Speed: 30.3ms track, 16.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 22: 720x1280 17.6ms,
# Speed: 34.6ms track, 17.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 23: 720x1280 15.7ms,
# Speed: 39.4ms track, 15.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 24: 720x1280 15.2ms,
# Speed: 37.6ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 25: 720x1280 15.3ms,
# Speed: 35.0ms track, 15.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 26: 720x1280 15.0ms,
# Speed: 33.9ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 27: 720x1280 15.2ms,
# Speed: 34.6ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 28: 720x1280 15.1ms,
# Speed: 34.5ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 29: 720x1280 15.0ms,
# Speed: 35.1ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 30: 720x1280 14.9ms,
# Speed: 33.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 31: 720x1280 15.2ms,
# Speed: 35.0ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 32: 720x1280 14.9ms,
# Speed: 36.4ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 33: 720x1280 14.9ms,
# Speed: 38.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 34: 720x1280 14.9ms,
# Speed: 40.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 35: 720x1280 15.1ms,
# Speed: 39.9ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 36: 720x1280 14.4ms,
# Speed: 37.5ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 37: 720x1280 15.0ms,
# Speed: 41.1ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 38: 720x1280 15.0ms,
# Speed: 46.9ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 39: 720x1280 15.0ms,
# Speed: 45.4ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 40: 720x1280 14.9ms,
# Speed: 47.8ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 41: 720x1280 14.9ms,
# Speed: 47.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 42: 720x1280 15.1ms,
# Speed: 46.3ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 43: 720x1280 14.9ms,
# Speed: 44.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 44: 720x1280 14.8ms,
# Speed: 42.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 45: 720x1280 14.9ms,
# Speed: 42.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 46: 720x1280 14.9ms,
# Speed: 42.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 47: 720x1280 14.8ms,
# Speed: 42.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 48: 720x1280 14.8ms,
# Speed: 42.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 49: 720x1280 14.9ms,
# Speed: 42.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 50: 720x1280 14.9ms,
# Speed: 42.1ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 51: 720x1280 15.2ms,
# Speed: 58.0ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 52: 720x1280 14.4ms,
# Speed: 57.2ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 53: 720x1280 14.9ms,
# Speed: 43.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 54: 720x1280 14.9ms,
# Speed: 40.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 55: 720x1280 14.8ms,
# Speed: 68.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 56: 720x1280 14.9ms,
# Speed: 40.5ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 57: 720x1280 14.8ms,
# Speed: 41.2ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 58: 720x1280 14.9ms,
# Speed: 40.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 59: 720x1280 14.8ms,
# Speed: 39.9ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 60: 720x1280 14.8ms,
# Speed: 41.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 61: 720x1280 14.8ms,
# Speed: 41.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 62: 720x1280 14.8ms,
# Speed: 40.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 63: 720x1280 15.0ms,
# Speed: 40.9ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 64: 720x1280 14.8ms,
# Speed: 38.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 65: 720x1280 14.9ms,
# Speed: 39.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 66: 720x1280 14.8ms,
# Speed: 38.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 67: 720x1280 14.8ms,
# Speed: 38.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 68: 720x1280 14.8ms,
# Speed: 38.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 69: 720x1280 14.8ms,
# Speed: 39.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 70: 720x1280 14.8ms,
# Speed: 38.4ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 71: 720x1280 14.9ms,
# Speed: 38.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 72: 720x1280 15.0ms,
# Speed: 38.0ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 73: 720x1280 14.9ms,
# Speed: 38.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 74: 720x1280 14.7ms,
# Speed: 37.6ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 75: 720x1280 16.5ms,
# Speed: 39.4ms track, 16.5ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 76: 720x1280 14.8ms,
# Speed: 38.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 77: 720x1280 15.0ms,
# Speed: 38.8ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 78: 720x1280 14.8ms,
# Speed: 37.9ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 79: 720x1280 15.0ms,
# Speed: 38.2ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 80: 720x1280 14.9ms,
# Speed: 38.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 81: 720x1280 15.6ms,
# Speed: 37.4ms track, 15.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 82: 720x1280 14.8ms,
# Speed: 38.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 83: 720x1280 14.8ms,
# Speed: 37.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 84: 720x1280 14.9ms,
# Speed: 38.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 85: 720x1280 15.3ms,
# Speed: 37.4ms track, 15.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 86: 720x1280 15.0ms,
# Speed: 37.6ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 87: 720x1280 14.9ms,
# Speed: 37.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 88: 720x1280 14.8ms,
# Speed: 37.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 89: 720x1280 14.8ms,
# Speed: 37.9ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 90: 720x1280 14.8ms,
# Speed: 36.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 91: 720x1280 14.9ms,
# Speed: 37.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 92: 720x1280 14.8ms,
# Speed: 37.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 93: 720x1280 14.9ms,
# Speed: 38.4ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 94: 720x1280 15.0ms,
# Speed: 37.9ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 95: 720x1280 14.8ms,
# Speed: 37.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 96: 720x1280 14.8ms,
# Speed: 66.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 97: 720x1280 15.1ms,
# Speed: 37.0ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 98: 720x1280 14.9ms,
# Speed: 36.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 99: 720x1280 14.8ms,
# Speed: 36.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 100: 720x1280 15.0ms,
# Speed: 37.3ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 101: 720x1280 13.7ms,
# Speed: 36.4ms track, 13.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 102: 720x1280 14.8ms,
# Speed: 36.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 103: 720x1280 15.0ms,
# Speed: 37.2ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 104: 720x1280 14.9ms,
# Speed: 39.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 105: 720x1280 14.7ms,
# Speed: 36.4ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 106: 720x1280 15.0ms,
# Speed: 37.5ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# 107: 720x1280 14.4ms, 1 apple
# Speed: 36.8ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# 108: 720x1280 14.5ms, 1 apple
# Speed: 36.2ms track, 14.5ms solution per image at shape (1, 3, 720, 1280)
#
# 109: 720x1280 14.6ms, 1 apple
# Speed: 36.6ms track, 14.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 110: 720x1280 14.8ms,
# Speed: 36.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 111: 720x1280 14.7ms,
# Speed: 36.3ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 112: 720x1280 14.8ms,
# Speed: 36.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 113: 720x1280 14.9ms,
# Speed: 36.4ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 114: 720x1280 14.9ms,
# Speed: 36.1ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 115: 720x1280 14.8ms,
# Speed: 36.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 116: 720x1280 14.9ms,
# Speed: 36.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 117: 720x1280 14.3ms,
# Speed: 36.3ms track, 14.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 118: 720x1280 14.7ms,
# Speed: 36.4ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 119: 720x1280 14.9ms,
# Speed: 36.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 120: 720x1280 14.8ms,
# Speed: 36.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 121: 720x1280 14.7ms,
# Speed: 36.1ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 122: 720x1280 15.0ms,
# Speed: 37.2ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 123: 720x1280 14.9ms,
# Speed: 36.4ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 124: 720x1280 14.8ms,
# Speed: 35.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 125: 720x1280 14.8ms,
# Speed: 36.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 126: 720x1280 15.0ms,
# Speed: 37.2ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 127: 720x1280 14.9ms,
# Speed: 36.5ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 128: 720x1280 14.8ms,
# Speed: 36.4ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 129: 720x1280 15.0ms,
# Speed: 36.4ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 130: 720x1280 14.9ms,
# Speed: 36.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 131: 720x1280 14.9ms,
# Speed: 37.0ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 132: 720x1280 14.8ms,
# Speed: 36.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 133: 720x1280 13.9ms,
# Speed: 36.7ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 134: 720x1280 14.9ms,
# Speed: 35.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 135: 720x1280 14.8ms,
# Speed: 37.2ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 136: 720x1280 14.8ms,
# Speed: 36.3ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 137: 720x1280 14.9ms,
# Speed: 64.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 138: 720x1280 14.7ms,
# Speed: 35.8ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 139: 720x1280 14.8ms,
# Speed: 35.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 140: 720x1280 14.9ms,
# Speed: 37.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 141: 720x1280 14.1ms,
# Speed: 39.2ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 142: 720x1280 14.8ms,
# Speed: 35.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 143: 720x1280 14.8ms,
# Speed: 36.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 144: 720x1280 14.9ms,
# Speed: 35.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 145: 720x1280 14.9ms,
# Speed: 35.8ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 146: 720x1280 14.4ms,
# Speed: 36.3ms track, 14.4ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 147: 720x1280 15.0ms,
# Speed: 35.6ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 148: 720x1280 14.8ms,
# Speed: 36.2ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 149: 720x1280 14.8ms,
# Speed: 35.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 150: 720x1280 14.8ms,
# Speed: 36.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 151: 720x1280 15.0ms,
# Speed: 36.3ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 152: 720x1280 14.7ms,
# Speed: 35.6ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 153: 720x1280 14.1ms,
# Speed: 35.6ms track, 14.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 154: 720x1280 14.9ms,
# Speed: 36.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 155: 720x1280 15.3ms,
# Speed: 36.0ms track, 15.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 156: 720x1280 14.6ms,
# Speed: 36.2ms track, 14.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 157: 720x1280 14.8ms,
# Speed: 35.9ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 158: 720x1280 15.0ms,
# Speed: 36.2ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 159: 720x1280 14.8ms,
# Speed: 36.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 160: 720x1280 14.8ms,
# Speed: 35.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 161: 720x1280 14.8ms,
# Speed: 35.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 162: 720x1280 14.9ms,
# Speed: 45.0ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 163: 720x1280 15.1ms,
# Speed: 42.5ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 164: 720x1280 14.9ms,
# Speed: 41.1ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 165: 720x1280 15.1ms,
# Speed: 36.0ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 166: 720x1280 15.2ms,
# Speed: 35.9ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 167: 720x1280 14.9ms,
# Speed: 35.7ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 168: 720x1280 14.9ms,
# Speed: 35.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 169: 720x1280 14.8ms,
# Speed: 38.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 170: 720x1280 14.8ms,
# Speed: 35.2ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 171: 720x1280 14.7ms,
# Speed: 35.7ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 172: 720x1280 14.8ms,
# Speed: 36.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 173: 720x1280 14.8ms,
# Speed: 38.1ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 174: 720x1280 14.7ms,
# Speed: 34.7ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 175: 720x1280 14.7ms,
# Speed: 35.2ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 176: 720x1280 14.6ms,
# Speed: 35.6ms track, 14.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 177: 720x1280 15.3ms,
# Speed: 36.0ms track, 15.3ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 178: 720x1280 14.7ms,
# Speed: 51.5ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 179: 720x1280 14.8ms,
# Speed: 34.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 180: 720x1280 14.8ms,
# Speed: 35.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 181: 720x1280 14.8ms,
# Speed: 35.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 182: 720x1280 14.8ms,
# Speed: 35.4ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 183: 720x1280 14.8ms,
# Speed: 34.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 184: 720x1280 14.8ms,
# Speed: 35.4ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 185: 720x1280 14.9ms,
# Speed: 35.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 186: 720x1280 14.9ms,
# Speed: 35.1ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 187: 720x1280 14.8ms,
# Speed: 34.9ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 188: 720x1280 14.8ms,
# Speed: 35.4ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 189: 720x1280 14.8ms,
# Speed: 35.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 190: 720x1280 14.9ms,
# Speed: 35.9ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 191: 720x1280 14.8ms,
# Speed: 35.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 192: 720x1280 14.8ms,
# Speed: 35.0ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 193: 720x1280 14.8ms,
# Speed: 34.7ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 194: 720x1280 15.0ms,
# Speed: 38.1ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 195: 720x1280 14.9ms,
# Speed: 34.6ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 196: 720x1280 14.8ms,
# Speed: 34.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 197: 720x1280 14.9ms,
# Speed: 34.3ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 198: 720x1280 14.8ms,
# Speed: 35.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 199: 720x1280 15.0ms,
# Speed: 36.0ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 200: 720x1280 14.8ms,
# Speed: 35.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 201: 720x1280 14.8ms,
# Speed: 34.8ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 202: 720x1280 14.8ms,
# Speed: 35.5ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 203: 720x1280 15.2ms,
# Speed: 35.9ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 204: 720x1280 15.9ms,
# Speed: 35.1ms track, 15.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 205: 720x1280 15.1ms,
# Speed: 38.4ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 206: 720x1280 15.0ms,
# Speed: 37.9ms track, 15.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 207: 720x1280 14.8ms,
# Speed: 37.6ms track, 14.8ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 208: 720x1280 14.7ms,
# Speed: 40.9ms track, 14.7ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 209: 720x1280 13.9ms,
# Speed: 39.4ms track, 13.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 210: 720x1280 14.6ms,
# Speed: 39.5ms track, 14.6ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 211: 720x1280 15.4ms,
# Speed: 36.7ms track, 15.4ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 212: 720x1280 14.9ms,
# Speed: 70.2ms track, 14.9ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 213: 720x1280 15.2ms,
# Speed: 40.3ms track, 15.2ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 214: 720x1280 14.0ms,
# Speed: 38.6ms track, 14.0ms solution per image at shape (1, 3, 720, 1280)
#
# WARNING ⚠️ No tracks found.
# 215: 720x1280 15.1ms,
# Speed: 38.1ms track, 15.1ms solution per image at shape (1, 3, 720, 1280)
#
# Video frame is empty or processing is complete.
